# %% [markdown]
# ##  Red Wine Quality prediction using logistic regression

# %%
# red wine quality prediction using logistic regression

from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1092, 828)
        Form.setStyleSheet("\n"
"background-color: qlineargradient(spread:reflect, x1:0.498, y1:0.159591, x2:1, y2:0.165, stop:0.0547264 rgba(18, 109, 197, 255), stop:0.228856 rgba(44, 119, 215, 255), stop:1 rgba(255, 255, 255, 255));")
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(210, 30, 691, 101))
        self.frame.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-width: 2px;\n"
"border-radius: 50px;\n"
"")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(100, 30, 481, 41))
        self.label.setStyleSheet("color: rgb(9, 15, 130);\n"
"font: 20pt \"Stencil\";\n"
"")
        self.label.setAlignment(QtCore.Qt.AlignCenter)
        self.label.setObjectName("label")
        self.frame_2 = QtWidgets.QFrame(Form)
        self.frame_2.setGeometry(QtCore.QRect(40, 160, 1021, 441))
        self.frame_2.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius : 50px;\n"
"font: 12pt \"Palatino Linotype\";")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.label_2 = QtWidgets.QLabel(self.frame_2)
        self.label_2.setGeometry(QtCore.QRect(60, 50, 81, 31))
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.frame_2)
        self.label_3.setGeometry(QtCore.QRect(60, 110, 141, 31))
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame_2)
        self.label_4.setGeometry(QtCore.QRect(60, 180, 161, 31))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame_2)
        self.label_5.setGeometry(QtCore.QRect(60, 240, 131, 31))
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(self.frame_2)
        self.label_6.setGeometry(QtCore.QRect(60, 300, 151, 41))
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(self.frame_2)
        self.label_7.setGeometry(QtCore.QRect(60, 370, 141, 31))
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(self.frame_2)
        self.label_8.setGeometry(QtCore.QRect(550, 50, 211, 31))
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(self.frame_2)
        self.label_9.setGeometry(QtCore.QRect(550, 110, 191, 21))
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(self.frame_2)
        self.label_10.setGeometry(QtCore.QRect(550, 170, 131, 31))
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(self.frame_2)
        self.label_11.setGeometry(QtCore.QRect(550, 230, 121, 41))
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(self.frame_2)
        self.label_12.setGeometry(QtCore.QRect(550, 300, 141, 41))
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(self.frame_2)
        self.label_13.setGeometry(QtCore.QRect(550, 360, 131, 41))
        self.label_13.setObjectName("label_13")
        self.type_ed = QtWidgets.QLineEdit(self.frame_2)
        self.type_ed.setGeometry(QtCore.QRect(250, 60, 241, 31))
        self.type_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.type_ed.setObjectName("type_ed")
        self.vol_ed = QtWidgets.QLineEdit(self.frame_2)
        self.vol_ed.setGeometry(QtCore.QRect(250, 180, 241, 31))
        self.vol_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.vol_ed.setObjectName("vol_ed")
        self.fix_ed = QtWidgets.QLineEdit(self.frame_2)
        self.fix_ed.setGeometry(QtCore.QRect(250, 120, 241, 31))
        self.fix_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.fix_ed.setObjectName("fix_ed")
        self.resi_ed = QtWidgets.QLineEdit(self.frame_2)
        self.resi_ed.setGeometry(QtCore.QRect(250, 300, 241, 31))
        self.resi_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.resi_ed.setObjectName("resi_ed")
        self.cit_ed = QtWidgets.QLineEdit(self.frame_2)
        self.cit_ed.setGeometry(QtCore.QRect(250, 240, 241, 31))
        self.cit_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.cit_ed.setObjectName("cit_ed")
        self.chlo_ed = QtWidgets.QLineEdit(self.frame_2)
        self.chlo_ed.setGeometry(QtCore.QRect(250, 370, 241, 31))
        self.chlo_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.chlo_ed.setObjectName("chlo_ed")
        self.free_ed = QtWidgets.QLineEdit(self.frame_2)
        self.free_ed.setGeometry(QtCore.QRect(750, 50, 241, 31))
        self.free_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.free_ed.setObjectName("free_ed")
        self.total_ed = QtWidgets.QLineEdit(self.frame_2)
        self.total_ed.setGeometry(QtCore.QRect(750, 110, 241, 31))
        self.total_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.total_ed.setObjectName("total_ed")
        self.den_ed = QtWidgets.QLineEdit(self.frame_2)
        self.den_ed.setGeometry(QtCore.QRect(750, 180, 241, 31))
        self.den_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.den_ed.setObjectName("den_ed")
        self.ph_ed = QtWidgets.QLineEdit(self.frame_2)
        self.ph_ed.setGeometry(QtCore.QRect(750, 240, 241, 31))
        self.ph_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.ph_ed.setObjectName("ph_ed")
        self.sul_ed = QtWidgets.QLineEdit(self.frame_2)
        self.sul_ed.setGeometry(QtCore.QRect(750, 310, 241, 31))
        self.sul_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.sul_ed.setObjectName("sul_ed")
        self.alco_ed = QtWidgets.QLineEdit(self.frame_2)
        self.alco_ed.setGeometry(QtCore.QRect(750, 370, 241, 31))
        self.alco_ed.setStyleSheet("color: rgb(6, 6, 6);\n"
"background-color: rgb(227, 227, 227);\n"
"font: 11pt \"Microsoft YaHei\";")
        self.alco_ed.setObjectName("alco_ed")
        self.frame_3 = QtWidgets.QFrame(Form)
        self.frame_3.setGeometry(QtCore.QRect(40, 640, 1021, 141))
        self.frame_3.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius: 30px;\n"
"font: 15pt \"Palatino Linotype\";")
        self.frame_3.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_3.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_3.setObjectName("frame_3")
        self.label_14 = QtWidgets.QLabel(self.frame_3)
        self.label_14.setGeometry(QtCore.QRect(80, 20, 461, 41))
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(self.frame_3)
        self.label_15.setGeometry(QtCore.QRect(300, 70, 221, 41))
        self.label_15.setObjectName("label_15")
        self.result = QtWidgets.QLabel(self.frame_3)
        self.result.setGeometry(QtCore.QRect(560, 80, 221, 41))
        font = QtGui.QFont()
        font.setFamily("Palatino Linotype")
        font.setPointSize(15)
        font.setBold(False)
        font.setItalic(False)
        font.setUnderline(False)
        font.setWeight(50)
        self.result.setFont(font)
        self.result.setText("")
        self.result.setObjectName("result")
        self.pushButton = QtWidgets.QPushButton(self.frame_3)
        self.pushButton.setGeometry(QtCore.QRect(570, 30, 171, 28))
        self.pushButton.setStyleSheet("background-color:rgb(43, 146, 255);\n"
"font: 13pt \"Stencil\";\n"
"color: rgb(255, 255, 255);\n"
"border-radius:10px;\n"
"")
        self.pushButton.setObjectName("pushButton")
        self.pushButton.setCursor(QtCore.Qt.PointingHandCursor)
        
        self.pushButton.clicked.connect(self.predict)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
        
    def predict(self):
        a = self.type_ed.text()
        x1 = str(a)
        
        b = self.fix_ed.text()
        x2 = float(b)
        
        c = self.vol_ed.text()
        x3 = float(c)
        
        d = self.cit_ed.text()
        x4 = float(d)
        
        e = self.resi_ed.text()
        x5 = float(e)
        
        f = self.chlo_ed.text()
        x6 = float(f)
        
        g = self.free_ed.text()
        x7 = int(g)
        
        h = self.total_ed.text()
        x8 = int(h)
        
        i = self.den_ed.text()
        x9 = float(i)
        
        j = self.ph_ed.text()
        x10 = float(j)
        
        k = self.sul_ed.text()
        x11 = float(k)
        
        l = self.alco_ed.text()
        x12 = float(l)
        
        print(x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12)
        
        import pandas as pd
        path = "D:/2022projects/KNN/Winequalitydatatset - 2/Wine-Quality-Dataset-master/winequalityred.csv"
        data = pd.read_csv(path)

        data['fixed acidity'] = data['fixed acidity'].fillna(value=0)
        data['volatile acidity'] = data['volatile acidity'].fillna(value=0)
        data['citric acid'] = data['citric acid'].fillna(value=0)
        data['residual sugar'] = data['residual sugar'].fillna(value=0)
        data['chlorides'] = data['chlorides'].fillna(value=0)
        data['free sulfur dioxide'] = data['free sulfur dioxide'].fillna(value=0)
        data['total sulfur dioxide'] = data['total sulfur dioxide'].fillna(value=0)
        data['density'] = data['density'].fillna(value=0)
        data['pH'] = data['pH'].fillna(value=0)
        data['sulphates'] = data['sulphates'].fillna(value=0)
        data['alcohol'] = data['alcohol'].fillna(value=0)
        data['quality'] = data['quality'].fillna(value=0)

        x = data.drop(['type','quality'],'columns')
        y = data.quality
        
        import sklearn
        from sklearn.model_selection import train_test_split
        x_train , x_test , y_train , y_test = train_test_split(x,y ,train_size=0.8)
        
        from sklearn.preprocessing import StandardScaler
        sc =  StandardScaler()
        x_train = sc.fit_transform(x_train)
        y_test = sc.transform(x_test)

        from sklearn.linear_model import LogisticRegression
        model = LogisticRegression()
        model.fit(x_train , y_train)

        y_pred = model.predict(x_test)
        res = model.predict([[x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12]])
        res = str(res)
        self.result.setText(res)
        print("Prediction:", res)
        

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Wine Quality Prediction"))
        self.label.setText(_translate("Form", "WINE QUALITY PREDICTION"))
        self.label_2.setText(_translate("Form", "Type:"))
        self.label_3.setText(_translate("Form", "Fixed Acidity:"))
        self.label_4.setText(_translate("Form", "Volatile Acidity:"))
        self.label_5.setText(_translate("Form", "Citric Acid:"))
        self.label_6.setText(_translate("Form", "Residual Sugar:"))
        self.label_7.setText(_translate("Form", "Chlorides:"))
        self.label_8.setText(_translate("Form", "Free Sulfurdioxide:"))
        self.label_9.setText(_translate("Form", "Total Sulfurdioxide:"))
        self.label_10.setText(_translate("Form", "Density:"))
        self.label_11.setText(_translate("Form", "pH:"))
        self.label_12.setText(_translate("Form", "Sulphates:"))
        self.label_13.setText(_translate("Form", "Alcohol:"))
        self.label_14.setText(_translate("Form", "Click here to predict red wine quality:"))
        self.label_15.setText(_translate("Form", "Red Wine Quality:"))
        self.pushButton.setText(_translate("Form", "PREDICT"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# red 7.4 0.7 0.0 1.9 0.076 11 34 0.9978 3.351 0.56 9.4
# C:\Users\91998\AppData\Local\Temp\ipykernel_12008\637703056.py:242: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = data.drop(['type','quality'],'columns')
# C:\Users\91998\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# Prediction: [5]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\91998\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
